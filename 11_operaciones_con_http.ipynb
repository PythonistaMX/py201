# %% [markdown]
# [![imagenes/pythonista.png](imagenes/pythonista.png)](https://pythonista.io)

# %% [markdown]
# Las bibliotecas de recursos contenidos en los paquetes *django.urls* y *django.http* son muy extensas y capaces de ofrecer funcionalidades especializadas que permiten desarrollar servicios web avanzados.
#
# A continuación se estudiarán algunas de ellas.

# %% [markdown]
# ## Obtención de datos a partir de una URL.
#
# Previamente se estudió la funcionalidad básica de *django.urls.path()* realizando las siguientes operaciones:
#
# * Identificando un patrón de URL.
# * Llamando a una función de vista relacionada con el patrón.
# * Ingresando el objeto *request* como argumento de la función de vista.
#
# Esta funcionalidad puede ser extendida permitiendo no sólo identificar un patrón de URL, sino identificando y obteniendo datos a partir de la URL.
#
# La sintaxis el la siguiente:
#
# * La cadena de caracteres correspondiente al patron de URL puede contener un texto delimitado por los signos *&lt;* y *&gt;*.
# * Este texto delimitado define un par ```<tipo>:<nombre>```.
# * En caso de que el segmento de URL de una petición coincida con el tipo de dato definido, este será capturado como un valor y ligado al nombre correspondiente.
#
# ```python
# path('{patrón}/<<tipo>:<nombre 1>>/<{<tipo>:<nombre 2>>/ ... / <<tipo>:<nombre n>>', <funcion de vista>, <argumentos>)
# ```
# De tal forma que si el segmento de la URL coincide con el tipo inidicado, éste será ligado al nombre con el que se encuentra relacionado.

# %%
### Tipos de datos identificables en una URL:

* string
* int
*

# %% [markdown]
# ** Ejemplos:**

# %%
help(django.http)
# Out:
# Help on package django.http in django:
#
# NAME
#     django.http
#
# PACKAGE CONTENTS
#     cookie
#     multipartparser
#     request
#     response
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         django.http.request.RawPostDataException
#         django.http.response.Http404
#     builtins.OSError(builtins.Exception)
#         django.http.request.UnreadablePostError
#     builtins.ValueError(builtins.Exception)
#         django.http.response.BadHeaderError
#     builtins.object
#         django.http.request.HttpRequest
#     django.http.response.HttpResponseBase(builtins.object)
#         django.http.response.HttpResponse
#             django.http.response.HttpResponseBadRequest
#             django.http.response.HttpResponseForbidden
#             django.http.response.HttpResponseGone
#             django.http.response.HttpResponseNotAllowed
#             django.http.response.HttpResponseNotFound
#             django.http.response.HttpResponseNotModified
#             django.http.response.HttpResponseServerError
#             django.http.response.JsonResponse
#         django.http.response.StreamingHttpResponse
#             django.http.response.FileResponse
#     django.http.response.HttpResponseRedirectBase(django.http.response.HttpResponse)
#         django.http.response.HttpResponsePermanentRedirect
#         django.http.response.HttpResponseRedirect
#     django.utils.datastructures.MultiValueDict(builtins.dict)
#         django.http.request.QueryDict
#     http.cookies.BaseCookie(builtins.dict)
#         http.cookies.SimpleCookie
#
#     class BadHeaderError(builtins.ValueError)
#      |  Inappropriate argument value (of correct type).
#      |
#      |  Method resolution order:
#      |      BadHeaderError
#      |      builtins.ValueError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.ValueError:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      helper for pickle
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class FileResponse(StreamingHttpResponse)
#      |  A streaming HTTP response class optimized for files.
#      |
#      |  Method resolution order:
#      |      FileResponse
#      |      StreamingHttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, *args, as_attachment=False, filename='', **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  set_headers(self, filelike)
#      |      Set some common response headers (Content-Length, Content-Type, and
#      |      Content-Disposition) based on the `filelike` response content.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  block_size = 4096
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from StreamingHttpResponse:
#      |
#      |  __iter__(self)
#      |
#      |  getvalue(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from StreamingHttpResponse:
#      |
#      |  content
#      |
#      |  streaming_content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from StreamingHttpResponse:
#      |
#      |  streaming = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __bytes__ = serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponseBase:
#      |
#      |  status_code = 200
#
#     class Http404(builtins.Exception)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      Http404
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      helper for pickle
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class HttpRequest(builtins.object)
#      |  A basic HTTP request.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  build_absolute_uri(self, location=None)
#      |      Build an absolute URI from the location and the variables available in
#      |      this request. If no ``location`` is specified, build the absolute URI
#      |      using request.get_full_path(). If the location is absolute, convert it
#      |      to an RFC 3987 compliant URI and return it. If location is relative or
#      |      is scheme-relative (i.e., ``//example.com/``), urljoin() it to a base
#      |      URL constructed from the request variables.
#      |
#      |  close(self)
#      |
#      |  get_full_path(self, force_append_slash=False)
#      |
#      |  get_full_path_info(self, force_append_slash=False)
#      |
#      |  get_host(self)
#      |      Return the HTTP host using the environment or request headers.
#      |
#      |  get_port(self)
#      |      Return the port number for the request as a string.
#      |
#      |  get_raw_uri(self)
#      |      Return an absolute URI from variables available in this request. Skip
#      |      allowed hosts protection, so may return insecure URI.
#      |
#      |  get_signed_cookie(self, key, default=<object object at 0x7fa365745150>, salt='', max_age=None)
#      |      Attempt to return a signed cookie. If the signature fails or the
#      |      cookie has expired, raise an exception, unless the `default` argument
#      |      is provided,  in which case return that value.
#      |
#      |  is_ajax(self)
#      |
#      |  is_secure(self)
#      |
#      |  parse_file_upload(self, META, post_data)
#      |      Return a tuple of (POST QueryDict, FILES MultiValueDict).
#      |
#      |  read(self, *args, **kwargs)
#      |
#      |  readline(self, *args, **kwargs)
#      |
#      |  readlines(self)
#      |
#      |  xreadlines(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  body
#      |
#      |  encoding
#      |
#      |  scheme
#      |
#      |  upload_handlers
#
#     class HttpResponse(HttpResponseBase)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __bytes__ = serialize(self)
#      |
#      |  __init__(self, content=b'', *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponseBase:
#      |
#      |  status_code = 200
#
#     class HttpResponseBadRequest(HttpResponse)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseBadRequest
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 400
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __init__(self, content=b'', *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponseForbidden(HttpResponse)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseForbidden
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 403
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __init__(self, content=b'', *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponseGone(HttpResponse)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseGone
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 410
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __init__(self, content=b'', *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponseNotAllowed(HttpResponse)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseNotAllowed
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, permitted_methods, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 405
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __iter__(self)
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponseNotFound(HttpResponse)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseNotFound
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 404
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __init__(self, content=b'', *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponseNotModified(HttpResponse)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseNotModified
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 304
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponsePermanentRedirect(HttpResponseRedirectBase)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponsePermanentRedirect
#      |      HttpResponseRedirectBase
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 301
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseRedirectBase:
#      |
#      |  __init__(self, redirect_to, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseRedirectBase:
#      |
#      |  url
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponseRedirectBase:
#      |
#      |  allowed_schemes = ['http', 'https', 'ftp']
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __iter__(self)
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponseRedirect(HttpResponseRedirectBase)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseRedirect
#      |      HttpResponseRedirectBase
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 302
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseRedirectBase:
#      |
#      |  __init__(self, redirect_to, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseRedirectBase:
#      |
#      |  url
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponseRedirectBase:
#      |
#      |  allowed_schemes = ['http', 'https', 'ftp']
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __iter__(self)
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#
#     class HttpResponseServerError(HttpResponse)
#      |  An HTTP response class with a string as content.
#      |
#      |  This content that can be read, appended to, or replaced.
#      |
#      |  Method resolution order:
#      |      HttpResponseServerError
#      |      HttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  status_code = 500
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponse:
#      |
#      |  __bytes__ = serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  __init__(self, content=b'', *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  getvalue(self)
#      |
#      |  serialize(self)
#      |      Full HTTP message, including headers, as a bytestring.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponse:
#      |
#      |  content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponse:
#      |
#      |  streaming = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __contains__ = has_header(self, header)
# ...
#      |      associated with the key.
#      |
#      |  lists(self)
#      |      Yield (key, list) pairs.
#      |
#      |  update(self, *args, **kwargs)
#      |      Extend rather than replace existing key lists.
#      |
#      |  values(self)
#      |      Yield the last value on every key list.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from django.utils.datastructures.MultiValueDict:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.dict:
#      |
#      |  __contains__(self, key, /)
#      |      True if D has a key k, else False.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __len__(self, /)
#      |      Return len(self).
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  __sizeof__(...)
#      |      D.__sizeof__() -> size of D in memory, in bytes
#      |
#      |  keys(...)
#      |      D.keys() -> a set-like object providing a view on D's keys
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from builtins.dict:
#      |
#      |  __hash__ = None
#
#     class RawPostDataException(builtins.Exception)
#      |  You cannot access raw_post_data from a request that has
#      |  multipart/* POST data if it has been accessed via POST,
#      |  FILES, etc..
#      |
#      |  Method resolution order:
#      |      RawPostDataException
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __reduce__(...)
#      |      helper for pickle
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class SimpleCookie(BaseCookie)
#      |  SimpleCookie supports strings as cookie values.  When setting
#      |  the value using the dictionary assignment notation, SimpleCookie
#      |  calls the builtin str() to convert the value to a string.  Values
#      |  received from HTTP are kept as strings.
#      |
#      |  Method resolution order:
#      |      SimpleCookie
#      |      BaseCookie
#      |      builtins.dict
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  value_decode(self, val)
#      |      real_value, coded_value = value_decode(STRING)
#      |      Called prior to setting a cookie's value from the network
#      |      representation.  The VALUE is the value read from HTTP
#      |      header.
#      |      Override this function to modify the behavior of cookies.
#      |
#      |  value_encode(self, val)
#      |      real_value, coded_value = value_encode(VALUE)
#      |      Called prior to setting a cookie's value from the dictionary
#      |      representation.  The VALUE is the value being assigned.
#      |      Override this function to modify the behavior of cookies.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from BaseCookie:
#      |
#      |  __init__(self, input=None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  __setitem__(self, key, value)
#      |      Dictionary style assignment.
#      |
#      |  __str__ = output(self, attrs=None, header='Set-Cookie:', sep='\r\n')
#      |      Return a string suitable for HTTP.
#      |
#      |  js_output(self, attrs=None)
#      |      Return a string suitable for JavaScript.
#      |
#      |  load(self, rawdata)
#      |      Load cookies from a string (presumably HTTP_COOKIE) or
#      |      from a dictionary.  Loading cookies from a dictionary 'd'
#      |      is equivalent to calling:
#      |          map(Cookie.__setitem__, d.keys(), d.values())
#      |
#      |  output(self, attrs=None, header='Set-Cookie:', sep='\r\n')
#      |      Return a string suitable for HTTP.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from BaseCookie:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.dict:
#      |
#      |  __contains__(self, key, /)
#      |      True if D has a key k, else False.
#      |
#      |  __delitem__(self, key, /)
#      |      Delete self[key].
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __ge__(self, value, /)
#      |      Return self>=value.
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __getitem__(...)
#      |      x.__getitem__(y) <==> x[y]
#      |
#      |  __gt__(self, value, /)
#      |      Return self>value.
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __le__(self, value, /)
#      |      Return self<=value.
#      |
#      |  __len__(self, /)
#      |      Return len(self).
#      |
#      |  __lt__(self, value, /)
#      |      Return self<value.
#      |
#      |  __ne__(self, value, /)
#      |      Return self!=value.
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  __sizeof__(...)
#      |      D.__sizeof__() -> size of D in memory, in bytes
#      |
#      |  clear(...)
#      |      D.clear() -> None.  Remove all items from D.
#      |
#      |  copy(...)
#      |      D.copy() -> a shallow copy of D
#      |
#      |  fromkeys(iterable, value=None, /) from builtins.type
#      |      Returns a new dict with keys from iterable and values equal to value.
#      |
#      |  get(...)
#      |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#      |
#      |  items(...)
#      |      D.items() -> a set-like object providing a view on D's items
#      |
#      |  keys(...)
#      |      D.keys() -> a set-like object providing a view on D's keys
#      |
#      |  pop(...)
#      |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#      |      If key is not found, d is returned if given, otherwise KeyError is raised
#      |
#      |  popitem(...)
#      |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#      |      2-tuple; but raise KeyError if D is empty.
#      |
#      |  setdefault(...)
#      |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#      |
#      |  update(...)
#      |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#      |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#      |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#      |      In either case, this is followed by: for k in F:  D[k] = F[k]
#      |
#      |  values(...)
#      |      D.values() -> an object providing a view on D's values
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from builtins.dict:
#      |
#      |  __hash__ = None
#
#     class StreamingHttpResponse(HttpResponseBase)
#      |  A streaming HTTP response class with an iterator as content.
#      |
#      |  This should only be iterated once, when the response is streamed to the
#      |  client. However, it can be appended to or replaced with a new iterator
#      |  that wraps the original content (or yields entirely new content).
#      |
#      |  Method resolution order:
#      |      StreamingHttpResponse
#      |      HttpResponseBase
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, streaming_content=(), *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __iter__(self)
#      |
#      |  getvalue(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  content
#      |
#      |  streaming_content
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  streaming = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from HttpResponseBase:
#      |
#      |  __bytes__ = serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  __contains__ = has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  __delitem__(self, header)
#      |
#      |  __getitem__(self, header)
#      |
#      |  __setitem__(self, header, value)
#      |
#      |  close(self)
#      |      # The WSGI server must call this method upon completion of the request.
#      |      # See http://blog.dscpl.com.au/2012/10/obligations-for-calling-close-on.html
#      |
#      |  delete_cookie(self, key, path='/', domain=None)
#      |
#      |  flush(self)
#      |
#      |  get(self, header, alternate=None)
#      |
#      |  has_header(self, header)
#      |      Case-insensitive check for a header.
#      |
#      |  items(self)
#      |
#      |  make_bytes(self, value)
#      |      Turn a value into a bytestring encoded in the output charset.
#      |
#      |  readable(self)
#      |
#      |  seekable(self)
#      |
#      |  serialize_headers(self)
#      |      HTTP headers as a bytestring.
#      |
#      |  set_cookie(self, key, value='', max_age=None, expires=None, path='/', domain=None, secure=False, httponly=False, samesite=None)
#      |      Set a cookie.
#      |
#      |      ``expires`` can be:
#      |      - a string in the correct format,
#      |      - a naive ``datetime.datetime`` object in UTC,
#      |      - an aware ``datetime.datetime`` object in any time zone.
#      |      If it is a ``datetime.datetime`` object then calculate ``max_age``.
#      |
#      |  set_signed_cookie(self, key, value, salt='', **kwargs)
#      |
#      |  setdefault(self, key, value)
#      |      Set a header unless it has already been set.
#      |
#      |  tell(self)
#      |
#      |  writable(self)
#      |
#      |  write(self, content)
#      |
#      |  writelines(self, lines)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from HttpResponseBase:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  charset
#      |
#      |  reason_phrase
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from HttpResponseBase:
#      |
#      |  status_code = 200
#
#     class UnreadablePostError(builtins.OSError)
#      |  Base class for I/O related errors.
#      |
#      |  Method resolution order:
#      |      UnreadablePostError
#      |      builtins.OSError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.OSError:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  __reduce__(...)
#      |      helper for pickle
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.OSError:
#      |
#      |  characters_written
#      |
#      |  errno
#      |      POSIX exception code
#      |
#      |  filename
#      |      exception filename
#      |
#      |  filename2
#      |      second exception filename
#      |
#      |  strerror
#      |      exception strerror
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
# FUNCTIONS
#     parse_cookie(cookie)
#         Return a dictionary parsed from a `Cookie:` header string.
#
# DATA
#     __all__ = ['SimpleCookie', 'parse_cookie', 'HttpRequest', 'QueryDict',...
#
# FILE
#     /home/oi/pythonista/lib/python3.6/site-packages/django/http/__init__.py

# %% [markdown]
# <p style="text-align: center"><a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/80x15.png" /></a><br />Esta obra está bajo una <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Licencia Creative Commons Atribución 4.0 Internacional</a>.</p>
# <p style="text-align: center">&copy; José Luis Chiquete Valdivieso. 2019.</p>
